# %%
import pandas as pd
movies = pd.read_csv('/Users/apple/Downloads/Project/Movie-Recommender-System-Project/movies/tmdb_5000_movies.csv')
credits = pd.read_csv('/Users/apple/Downloads/Project/Movie-Recommender-System-Project/movies/tmdb_5000_credits.csv')

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head()
# budget
# homepage
# id
# original_language
# original_title
# popularity
# production_comapny
# production_countries
# release-date(not sure)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]
# 🎬 Keeping only the important columns from the 'movies' dataset:
# ✅ 'movie_id'   -> Unique ID for each movie 🆔
# 🎞️ 'title'     -> Name of the movie 🎥
# 📝 'overview'  -> Short summary of the movie 📖
# 🧬 'genres'    -> Types or categories (like Action, Comedy) 🎭
# 🔑 'keywords'  -> Important tags describing the movie 🏷️
# 👨‍🎤 'cast'     -> Main actors/actresses in the movie 🌟
# 🎬 'crew'      -> People who worked behind the scenes (like director) 👨‍💼

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
import ast  # 🧙‍♂️ 'ast' মডিউল ইমপোর্ট করা হচ্ছে

# 🧠 'ast' মানে Abstract Syntax Tree
# 📝 এটি ব্যবহার করে আপনি কোনো স্ট্রিং (যেটা দেখতে লিস্ট বা ডিকশনারির মত) 
#    সেটিকে নিরাপদভাবে পাইথনের আসল অবজেক্টে রূপান্তর করতে পারেন।
# 🚫 এটি 'eval' এর চেয়ে অনেক বেশি নিরাপদ!

# %%
def convert(text):
    L = []  # 🧺 একটা খালি লিস্ট তৈরি করা হলো যাতে 'name' গুলো রাখা যাবে
    for i in ast.literal_eval(text):  # 🔍 স্ট্রিং টাইপের ডাটা কে লিস্ট অফ ডিকশনারি তে রূপান্তর করা হচ্ছে
        L.append(i['name'])  # 🏷️ প্রতিটা ডিকশনারি থেকে 'name' কীগুলা বের করে লিস্টে যোগ করা হচ্ছে
    return L  # 🎁 সব নাম নিয়ে তৈরি লিস্টটি রিটার্ন করা হচ্ছে

# %% [markdown]
# একটি স্ট্রিং (text) ইনপুট হিসেবে নেওয়া হচ্ছে, যা আসলে একটি লিস্ট অফ ডিকশনারির মত দেখতে, এবং সেই ডিকশনারিগুলোর মধ্যে থাকা 'name' গুলোকেই বের করে একটি নতুন লিস্টে রাখা হচ্ছে।

# %%
movies.dropna(inplace=True)

# %%
movies['genres'] = movies['genres'].apply(convert)  # 🎬 প্রতিটি জেনার (genres) কলামে থাকা JSON টাইপ ডাটাকে list বানিয়ে নিচ্ছে
movies.head()  # 👀 উপরের দিকের ৫টা সারি প্রিন্ট করবে যাতে দেখতে পারো ডাটা ঠিকমতো প্রসেস হয়েছে কিনা
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %% [markdown]
# তুমি যেটা লিখছো সেটা হলো একটি Pandas DataFrame-এর genres নামক কলামে থাকা JSON স্ট্রিং টাইপের ডাটা প্রসেস করার প্রক্রিয়া। আসো নিচে ধাপে ধাপে ব্যাখ্যা করি পুরোটা:

# %%
movies['keywords'] = movies['keywords'].apply(convert)  # 🔑 প্রতিটা 'keywords' স্ট্রিংকে লিস্টে রূপান্তর করে
movies.head()  # 👀 উপরের ৫টি সারি দেখায় ডাটা ঠিকভাবে এসেছে কিনা তা চেক করার জন্য
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %% [markdown]
# keywords কলামে থাকা প্রতিটা সেল এমন একটা স্ট্রিং — যেটা দেখতে JSON-এর মতো (কিন্তু সেটা আসলে স্ট্রিং)।
# তুমি সেই স্ট্রিংগুলোকে লিস্ট অফ কিওয়ার্ড নাম এ রূপান্তর করছো।

# %%
import ast  # 🔧 ast মডিউল ইমপোর্ট করলাম যা স্ট্রিং থেকে পাইথন অবজেক্ট বানাতে সাহায্য করে

ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# ➡️ এই স্ট্রিংকে আসল পাইথন লিস্ট অবজেক্টে রূপান্তর করবে
# আউটপুট হবে:
# [
#   {'id': 28, 'name': 'Action'}, 
#   {'id': 12, 'name': 'Adventure'}, 
#   {'id': 14, 'name': 'Fantasy'}, 
#   {'id': 878, 'name': 'Science Fiction'}
# ]
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %% [markdown]
# তুমি যেটা করছো সেইটা হলো একটা স্ট্রিং টাইপের ডাটাকে (যেটা দেখতে JSON-এর মতো) — তাকে বাস্তব Python লিস্ট অবজেক্টে রূপান্তর করা।
# এই প্রক্রিয়াটা তুমি করছো ast.literal_eval() ফাংশনের মাধ্যমে।

# %%
def convert3(text):
    L = []  # 📝 ফাঁকা লিস্ট বানাচ্ছি যেখানে নামগুলো জমা হবে
    counter = 0  # 🔢 নাম গুনার জন্য কাউন্টার
    for i in ast.literal_eval(text):  # 🔧 স্ট্রিং থেকে লিস্ট অবজেক্টে রূপান্তর করছি
        if counter < 3:  # ⏳ প্রথম ৩ টা আইটেম নেবো শুধু
            L.append(i['name'])  # 🏷️ 'name' বের করে লিস্টে যোগ করবো
        counter += 1  # ➕ কাউন্টার বাড়াচ্ছি
    return L  # 🏁 শেষে প্রথম ৩টা নামের লিস্ট রিটার্ন করবো

# %% [markdown]
# তুমি একটা স্ট্রিং টাইপ JSON ডাটা থেকে শুধু প্রথম ৩টা ‘name’ ফিল্ড বের করে একটা লিস্ট বানাচ্ছো।

# %%
movies['cast'] = movies['cast'].apply(convert)  # 🎭 'cast' কলামের JSON স্ট্রিং থেকে নামগুলো বের করে লিস্টে রূপান্তর করবে
movies.head()  # 👀 প্রথম ৫টি সারি দেখাবে, যেন ডাটা ঠিকমতো এসেছে কিনা বুঝতে পারো
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %% [markdown]
# 🎯 ‘cast’ কলামের প্রতিটি ঘরে (cell) যেটা একটি stringified JSON (list of dict) —
# তাকে:
#
# ast.literal_eval() দিয়ে বাস্তব Python list এ রূপান্তর করছো।
#
# তারপর, প্রতিটি dict থেকে শুধুমাত্র 'name' ফিল্ড নিয়ে একটি নতুন লিস্ট বানাচ্ছো।
#
# সেই লিস্টটিই replace করে দিচ্ছো cast কলামে।

# %%
movies['cast'] = movies['cast'].apply(lambda x: x[0:3])  # 🎭 প্রতিটি 'cast' লিস্ট থেকে প্রথম ৩ টা সদস্যই নেবে

# %%
def fetch_director(text):
    L = []  # 📝 ফাঁকা লিস্ট যেখানে ডিরেক্টরের নামগুলো রাখা হবে
    for i in ast.literal_eval(text):  # 🔧 JSON স্ট্রিং থেকে আসল লিস্টে রূপান্তর
        if i['job'] == 'Director':  # 🎯 যদি কারো কাজ 'Director' হয়
            L.append(i['name'])  # 🏷️ তার নাম লিস্টে যোগ করো
    return L  # 🏁 শেষে ডিরেক্টরদের নামের লিস্ট রিটার্ন করো

# %% [markdown]
# JSON ফর্ম্যাটে থাকা crew কলামের মধ্যে থেকে শুধু 'Director' দের নাম বের করে লিস্টে রাখা।

# %%
movies['crew'] = movies['crew'].apply(fetch_director)  
# 🎯 'crew' কলামের JSON ডাটায় থেকে শুধুমাত্র 'Director' এর নাম আলাদা করে নিবে
# এবং সেই নামগুলো 'crew' কলামে রাখবে

# %% [markdown]
# 🔍 JSON ফরম্যাটে থাকা ডেটা থেকে শুধু পরিচালক (Director) এর নাম বের করে আনছো।

# %%
#movies['overview'] = movies['overview'].apply(lambda x:x.split())
movies.sample(5)
# Out:
#       movie_id              title  \
# 1572      9598               Babe
# 2423     13960                ATL
# 2877     10362         Two Lovers
# 4006     14137        Beer League
# 1836     88042  Parental Guidance
#
#                                                overview  \
# 1572  Babe is a little pig who doesn't quite know hi...
# 2423  As four friends prepare for life after high sc...
# 2877  A depressed man moves back in with his parents...
# 4006  An unemployed slacker (Lange) inspires his sof...
# 1836  Artie and Diane agree to look after their thre...
#
#                                 genres  \
# 1572  [Fantasy, Drama, Comedy, Family]
# 2423                           [Drama]
# 2877                  [Drama, Romance]
# 4006                          [Comedy]
# 1836                          [Comedy]
#
#                                                keywords  \
# 1572  [sheep, pig, affection, piglet, heroism, talki...
# 2423                                                 []
# 2877                     [love of one's life, neighbor]
# 4006                                  [baseball, sport]
# 1836                                                 []
#
#                                                    cast                  crew
# 1572  [Christine Cavanaugh, Miriam Margolyes, Danny ...        [Chris Noonan]
# 2423                     [T.I., Evan Ross, Jackie Long]  [Christian Robinson]
# 2877  [Joaquin Phoenix, Gwyneth Paltrow, Isabella Ro...          [James Gray]
# 4006      [Artie Lange, Ralph Macchio, Anthony DeSando]    [Frank Sebastiano]
# 1836        [Billy Crystal, Bette Midler, Marisa Tomei]        [Andy Fickman]

# %%
def collapse(L):
    L1 = []  # 📝 ফাঁকা লিস্ট যেখানে স্পেস ছাড়া নামগুলো জমা হবে
    for i in L:  # 🔄 প্রতিটি নামের উপর কাজ করবো
        L1.append(i.replace(" ",""))  # 🚫 স্পেস গুলো ফাঁকা করে নামগুলো নতুন লিস্টে যোগ করো
    return L1  # 🏁 স্পেস মুক্ত নামের লিস্ট রিটার্ন করো

# %% [markdown]
# একটি নামের লিস্টে থাকা প্রতিটি নাম থেকে সকল স্পেস (space) মুছে ফেলে একটি নতুন লিস্টে রাখা।

# %%
movies['cast'] = movies['cast'].apply(collapse)      # 🎭 'cast' লিস্ট থেকে স্পেস গুলো সরাবে
movies['crew'] = movies['crew'].apply(collapse)      # 👨‍💼 'crew' লিস্ট থেকে স্পেস মুছে দেবে
movies['genres'] = movies['genres'].apply(collapse)  # 🎨 'genres' লিস্ট থেকেও স্পেস সরানো হবে
movies['keywords'] = movies['keywords'].apply(collapse)  # 🔑 'keywords' লিস্ট থেকেও স্পেস মুছে দিবে

# %% [markdown]
# প্রতিটি কলামের ভেতরে থাকা লিস্ট অব স্ট্রিং থেকে স্পেস (space) মুছে ফেলা।

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]

# %%
movies['overview'] = movies['overview'].apply(lambda x: x.split())  
# ✂️ 'overview' টেক্সটকে ছোট ছোট শব্দে ভাগ করে একটি লিস্ট বানাবে

# %% [markdown]
# overview কলামে থাকা প্রতিটি টেক্সটকে "শব্দভিত্তিক লিস্টে" রূপান্তর করা।

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']
# ➕ 'overview', 'genres', 'keywords', 'cast', 'crew' এই পাঁচটা কলামের তথ্যগুলো একসাথে যোগ করে নতুন একটি 'tags' কলাম তৈরি করলো

# %% [markdown]
# ✅ মুভির বর্ণনা, ধরন, থিম, অভিনেতা ও পরিচালক — এই সব তথ্যকে একত্রে মিলিয়ে প্রতিটি মুভির একটি সামগ্রিক পরিচিতি বা tags ফিচার তৈরি করেছো।

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])
#new.head()

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))  
# 🔗 'tags' কলামে থাকা শব্দের লিস্টগুলোকে একসাথে স্পেস দিয়ে যোগ করে একটা বড়ো স্ট্রিং বানাচ্ছে

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words='english')
# 📚 CountVectorizer দিয়ে টেক্সটকে সংখ্যায় রূপান্তর করার জন্য সেটআপ করছো,
# 🔢 শুধু ৫০০০টা সবচেয়ে বেশি ব্যবহৃত শব্দ নেবে,
# 🚫 আর ইংরেজির সাধারণ 'stop words' (যেমন: the, is, at) বাদ দিবে

# %%
vector = cv.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# 🤝 Cosine Similarity ইম্পোর্ট করছো
# 📏 এটা ব্যবহার করে দুইটা টেক্সটের মধ্যে similarity (সাদৃশ্যতা) মাপা হয়

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.08964215, 0.06071767, ..., 0.02519763, 0.0277885 ,
#         0.        ],
#        [0.08964215, 1.        , 0.06350006, ..., 0.02635231, 0.        ,
#         0.        ],
#        [0.06071767, 0.06350006, 1.        , ..., 0.02677398, 0.        ,
#         0.        ],
#        ...,
#        [0.02519763, 0.02635231, 0.02677398, ..., 1.        , 0.07352146,
#         0.04774099],
#        [0.0277885 , 0.        , 0.        , ..., 0.07352146, 1.        ,
#         0.05264981],
#        [0.        , 0.        , 0.        , ..., 0.04774099, 0.05264981,
#         1.        ]])

# %%
new[new['title'] == 'The Lego Movie'].index[0]
# Out:
# 744

# %%
def recommend(movie):  # 🎬 ইউজার যে মুভি নাম দিবে সেটার উপর ভিত্তি করে রিকমেন্ডেশন দিবে
    index = new[new['title'] == movie].index[0]  # 🔍 ইউজার দেওয়া মুভির index খুঁজে বের করছে
    
    distances = sorted(
        list(enumerate(similarity[index])),  # 🧮 similarity array থেকে উক্ত মুভির সাথে অন্য মুভিগুলোর similarity বের করছে
        reverse=True,
        key = lambda x: x[1]  # 🔢 similarity স্কোর (index 1) অনুযায়ী descending order এ sort করছে
    )
    
    for i in distances[1:6]:  # 🔁 টপ 5 মুভি (excluding self i.e., distances[0]) প্রিন্ট করছে
        print(new.iloc[i[0]].title)  # 🖨️ similarity অনুযায়ী মুভির নাম দেখাচ্ছে

# %% [markdown]
# 🎯 ইউজার একটি মুভির নাম দিলে, সেই মুভির সাথে সবচেয়ে বেশি মিল থাকা অন্য ৫টি মুভির নাম সাজেস্ট করা।

# %%
recommend('Gandhi')
# Out:
# Gandhi, My Father
# The Wind That Shakes the Barley
# A Passage to India
# Guiana 1838
# Ramanujan

# %%
import pickle

# %%
pickle.dump(new,open('movie_list.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
